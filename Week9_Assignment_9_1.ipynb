# %% [markdown]
# <a href="https://colab.research.google.com/github/Ar8k/Assigment-2.2-CSS-Text-Styling/blob/main/Week9_Assignment_9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load the dataset into a pandas dataframe and answer the following questions:

# %% [markdown]
# Describe the structure of the diabetes dataset (size,features, data types)

# %%
from sklearn.datasets import load_diabetes
import pandas as pd


diabetes = load_diabetes() #loading in the dataset
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names) #making it into dataframe
df['target'] = diabetes.target

print("Shape: " , df.shape)
print("\nData types:")
print(df.dtypes)
print("\nFirst 5 rows: ")
print(df.head())
# Out:
# Shape:  (442, 11)
#
# Data types:
# age       float64
# sex       float64
# bmi       float64
# bp        float64
# s1        float64
# s2        float64
# s3        float64
# s4        float64
# s5        float64
# s6        float64
# target    float64
# dtype: object
#
# First 5 rows:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %% [markdown]
# Show the relationships between the target variable and the features using scatter plot and correlation analysis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

diabetes = load_diabetes() #loading in the dataset
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names) #making it into dataframe
df['target'] = diabetes.target
for feature in df.columns[:-1]: #making the scatter plots for the target vs feature
  plt.figure(figsize=(4,3))
  sns.scatterplot(x=df[feature], y=df['target'])
  plt.title(f"{feature} vs Target")
  plt.xlabel(feature)
  plt.ylabel("Target")
  plt.show()

  correlation = df.corr()['target'].sort_values(ascending=False) #The correlation
  print("Correlation:\n" , correlation)
# Out:
# Correlation:
#  target    1.000000
# bmi       0.586450
# s5        0.565883
# bp        0.441482
# s4        0.430453
# s6        0.382483
# s1        0.212022
# age       0.187889
# s2        0.174054
# sex       0.043062
# s3       -0.394789
# Name: target, dtype: float64
# Correlation:
#  target    1.000000
# bmi       0.586450
# s5        0.565883
# bp        0.441482
# s4        0.430453
# s6        0.382483
# s1        0.212022
# age       0.187889
# s2        0.174054
# sex       0.043062
# s3       -0.394789
# Name: target, dtype: float64
# Correlation:
#  target    1.000000
# bmi       0.586450
# s5        0.565883
# bp        0.441482
# s4        0.430453
# s6        0.382483
# s1        0.212022
# age       0.187889
# s2        0.174054
# sex       0.043062
# s3       -0.394789
# Name: target, dtype: float64
# Correlation:
#  target    1.000000
# bmi       0.586450
# s5        0.565883
# bp        0.441482
# s4        0.430453
# s6        0.382483
# s1        0.212022
# ...

# %% [markdown]
# Build a Simple Linear Regression Model (Single Feature):
#
# 1. Choose a single feature (body mass index) as the predictor variable and the s6 glu, blood sugar level as the target variable.
#
# 2. Split the dataset into training and testing sets.
#
# 3. Train a simple linear regression model using the training data.
#
# 4. Evaluate the model's accuracy using metrics such as mean squared error (MSE) or R-squared on both the training and testing sets.
#
# 5. Visualize the actual vs. predicted values of the target variable on the testing set.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score



diabetes = load_diabetes() #loading in the dataset
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names) #making it into dataframe
x = df[['bmi']] #defining x and y
y = df['s6']

x_train, x_test, y_train, y_test = train_test_split(

    x, y, test_size=0.2, random_state=42
    ) #splitting them into training sets

model = LinearRegression()
model.fit(x_train, y_train)

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test) #predicting
train_mse = mean_squared_error(y_train, y_train_pred) #evaluating
test_mse = mean_squared_error(y_test , y_test_pred)
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)
print(f"Training MSE: {train_mse:.4f}")
print(f"Testing MSE: {test_mse:.4f}")
print(f"Training R²: {train_r2:.4f}")
print(f"Testing R²: {test_r2:.4f}")

plt.figure(figsize=(5,4)) #making the plot
sns.scatterplot(x=y_test, y=y_test_pred)
plt.xlabel("Actual s6")
plt.ylabel("Predicted s6")
plt.title("Actual vs Predicted s6 levels")
plt.plot([y_test.min(), y_test.max()],
         y_test.min(), y_test.max(),
         'r--') #the time

plt.show()
# Out:
# Training MSE: 0.0020
# Testing MSE: 0.0018
# Training R²: 0.1640
# Testing R²: 0.0497
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1701459140.py in <cell line: 0>()
#      34 plt.ylabel("Predicted s6")
#      35 plt.title("Actual vs Predicted s6 levels")
# ---> 36 plt.plot([y_test.min(), y_test.max()],
#      37          y_test.min(), y_test.max(),
#      38          'r--') #the time
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %% [markdown]
# Build a Simple Linear Regression Model (Two Features):
#
# 1.Select two features (body mass index and age in years) as predictor variables and the s6 glu, blood sugar level as the target variable.
#
# 2.Split the dataset into training and testing sets.
# Train a simple linear regression model using the training data.
#
# 3.Assess the model's accuracy using metrics such as MSE or R-squared on both the training and testing sets.
#
# 4.Visualize the actual vs. predicted values of the target variable on the testing set.

# %%
diabetes = load_diabetes() #loading in the dataset
df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names) #making it into dataframe

x = df[['bmi', 'age']] #defining x and y
y = df['s6']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
    )#splitting them into training sets

model = LinearRegression()
model.fit(x_train, y_train) #Training

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test) #Predicting

print(f"Training MSE: {mean_squared_error(y_train, y_train_pred):.4f}")
print(f"Testing MSE: {mean_squared_error(y_test, y_test_pred):.4f}")
print(f"Training R²: {r2_score(y_train, y_train_pred):.4f}")
print(f"Testing R²: {r2_score(y_test, y_test_pred):.4f}")

plt.figure(figsize=(5,4)) #making the plot
sns.scatterplot(x=y_test, y=y_test_pred)
plt.xlabel("Actual s6")
plt.ylabel("Predicted s6")
plt.title("Actual vs Predicted s6 levels (Two Features)")
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         'r--')#the time

plt.show()
# Out:
# Training MSE: 0.0018
# Testing MSE: 0.0016
# Training R²: 0.2083
# Testing R²: 0.1564
